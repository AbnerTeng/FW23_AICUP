# %%
import pandas as pd
import numpy as np
import os
import warnings
import optuna
import pandas as pd
from tqdm import tqdm
os.environ['KMP_DUPLICATE_LIB_OK']='True'
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# %%
X = pd.read_csv("./data/train_feat.csv")
Y = pd.read_csv("./data/train_output.csv")

# %%
x_train, x_valid, y_train, y_valid = train_test_split(X, Y, test_size=0.2, random_state=507)

# %%
def objective(trial):
    params = {
        "verbose": -1,
        "metric": "mape",
        "num_iterations": trial.suggest_int("num_iterations", 100, 600), 
        "verbosity": -1,
        "bagging_freq": 1,
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 1.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 64, 2**10),
        "subsample": trial.suggest_float("subsample", 0.1, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.1, 1.0),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 10, 100),
        "max_bin": trial.suggest_int("max_bin", 255, 512),
    }

    model = LGBMRegressor(**params)
    model.fit(x_train, y_train)
    pred = model.predict(x_valid)
    mape = mean_absolute_percentage_error(y_valid, pred)
    # print(f"MAPE: {mape*100}")
    return mape

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2023-11-11 17:00:53,660] A new study created in memory with name: no-name-4389f503-eed8-495c-8a93-eef59eec7b82
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:00:54,257] Trial 0 finished with value: 0.10486679696854902 and parameters: {'num_iterations': 151, 'learning_rate': 0.05134320919484361, 'num_leaves': 414, 'subsample': 0.174738299754772, 'colsample_bytree': 0.8401435810538883, 'min_data_in_leaf': 20, 'max_bin': 274}. Best is trial 0 with value: 0.10486679696854902.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:00:55,286] Trial 1 finished with value: 0.10163216727694346 and parameters: {'num_iterations': 386, 'learning_rate': 0.04923059788024086, 'num_leaves': 760, 'subsample': 0.45122120910748653, 'colsample_bytree': 0.8407956218754967, 'min_data_in_leaf': 90, 'max_bin': 343}. Best is trial 1 with value: 0.10163216727694346.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:00:57,309] Trial 2 finished with value: 0.1038678027228092 and parameters: {'num_iterations': 443, 'learning_rate': 0.1337899326108272, 'num_leaves': 1023, 'subsample': 0.9855414755268451, 'colsample_bytree': 0.2631116934922664, 'min_data_in_leaf': 60, 'max_bin': 383}. Best is trial 1 with value: 0.10163216727694346.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:00:58,542] Trial 3 finished with value: 0.2883355978648913 and parameters: {'num_iterations': 532, 'learning_rate': 0.0013795869672088407, 'num_leaves': 992, 'subsample': 0.6946029042073733, 'colsample_bytree': 0.2006777397448226, 'min_data_in_leaf': 82, 'max_bin': 504}. Best is trial 1 with value: 0.10163216727694346.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:00,096] Trial 4 finished with value: 0.12298114354647423 and parameters: {'num_iterations': 366, 'learning_rate': 0.006112620889321614, 'num_leaves': 131, 'subsample': 0.8425004153837268, 'colsample_bytree': 0.8142377974684225, 'min_data_in_leaf': 86, 'max_bin': 500}. Best is trial 1 with value: 0.10163216727694346.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:00,726] Trial 5 finished with value: 0.3728811689551057 and parameters: {'num_iterations': 371, 'learning_rate': 0.0011431928618358842, 'num_leaves': 395, 'subsample': 0.29068649157926363, 'colsample_bytree': 0.10933407632338842, 'min_data_in_leaf': 50, 'max_bin': 365}. Best is trial 1 with value: 0.10163216727694346.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:01,720] Trial 6 finished with value: 0.09976714970413426 and parameters: {'num_iterations': 282, 'learning_rate': 0.053850927693717306, 'num_leaves': 378, 'subsample': 0.6155357011206812, 'colsample_bytree': 0.39288780260856504, 'min_data_in_leaf': 57, 'max_bin': 508}. Best is trial 6 with value: 0.09976714970413426.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:04,847] Trial 7 finished with value: 0.11632816108255231 and parameters: {'num_iterations': 338, 'learning_rate': 0.017995553961643516, 'num_leaves': 825, 'subsample': 0.5450342188691808, 'colsample_bytree': 0.18922237288574606, 'min_data_in_leaf': 11, 'max_bin': 410}. Best is trial 6 with value: 0.09976714970413426.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:05,863] Trial 8 finished with value: 0.11515001303199124 and parameters: {'num_iterations': 512, 'learning_rate': 0.005923613208577215, 'num_leaves': 533, 'subsample': 0.5620793338991625, 'colsample_bytree': 0.7655926406690056, 'min_data_in_leaf': 99, 'max_bin': 255}. Best is trial 6 with value: 0.09976714970413426.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:06,878] Trial 9 finished with value: 0.11605921745848718 and parameters: {'num_iterations': 468, 'learning_rate': 0.13929770522814827, 'num_leaves': 1006, 'subsample': 0.1667452546016244, 'colsample_bytree': 0.906026986758652, 'min_data_in_leaf': 50, 'max_bin': 430}. Best is trial 6 with value: 0.09976714970413426.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:08,135] Trial 10 finished with value: 0.12815185865150755 and parameters: {'num_iterations': 210, 'learning_rate': 0.41130554366418715, 'num_leaves': 126, 'subsample': 0.7346600031346212, 'colsample_bytree': 0.4514040318097774, 'min_data_in_leaf': 33, 'max_bin': 453}. Best is trial 6 with value: 0.09976714970413426.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:08,839] Trial 11 finished with value: 0.2432694363031067 and parameters: {'num_iterations': 264, 'learning_rate': 0.7408967023666547, 'num_leaves': 720, 'subsample': 0.42278617755185327, 'colsample_bytree': 0.6149894199460926, 'min_data_in_leaf': 71, 'max_bin': 329}. Best is trial 6 with value: 0.09976714970413426.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:09,580] Trial 12 finished with value: 0.10412222946809307 and parameters: {'num_iterations': 282, 'learning_rate': 0.04307365083790745, 'num_leaves': 688, 'subsample': 0.42998471413659706, 'colsample_bytree': 0.9561280262925215, 'min_data_in_leaf': 97, 'max_bin': 328}. Best is trial 6 with value: 0.09976714970413426.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:12,073] Trial 13 finished with value: 0.10497674757954636 and parameters: {'num_iterations': 584, 'learning_rate': 0.12237641164743661, 'num_leaves': 266, 'subsample': 0.5638134465249519, 'colsample_bytree': 0.4954729639268783, 'min_data_in_leaf': 36, 'max_bin': 308}. Best is trial 6 with value: 0.09976714970413426.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:12,458] Trial 14 finished with value: 0.13997403302983408 and parameters: {'num_iterations': 119, 'learning_rate': 0.016255902366142338, 'num_leaves': 587, 'subsample': 0.3506761228426344, 'colsample_bytree': 0.6567144982508636, 'min_data_in_leaf': 64, 'max_bin': 458}. Best is trial 6 with value: 0.09976714970413426.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:13,399] Trial 15 finished with value: 0.1008152840455204 and parameters: {'num_iterations': 296, 'learning_rate': 0.060073962898209154, 'num_leaves': 854, 'subsample': 0.6470489033762498, 'colsample_bytree': 0.3559477630516573, 'min_data_in_leaf': 76, 'max_bin': 348}. Best is trial 6 with value: 0.09976714970413426.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:14,088] Trial 16 finished with value: 0.11288297519820752 and parameters: {'num_iterations': 220, 'learning_rate': 0.2674967159464385, 'num_leaves': 356, 'subsample': 0.7025668395385019, 'colsample_bytree': 0.39245235997881467, 'min_data_in_leaf': 74, 'max_bin': 406}. Best is trial 6 with value: 0.09976714970413426.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:15,459] Trial 17 finished with value: 0.09981278686268051 and parameters: {'num_iterations': 296, 'learning_rate': 0.06828766253508742, 'num_leaves': 542, 'subsample': 0.6282227442877053, 'colsample_bytree': 0.3606484172875106, 'min_data_in_leaf': 39, 'max_bin': 471}. Best is trial 6 with value: 0.09976714970413426.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:16,783] Trial 18 finished with value: 0.18300103333157747 and parameters: {'num_iterations': 183, 'learning_rate': 0.8521429897125273, 'num_leaves': 534, 'subsample': 0.8264905557200302, 'colsample_bytree': 0.33465007327072815, 'min_data_in_leaf': 31, 'max_bin': 470}. Best is trial 6 with value: 0.09976714970413426.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:18,110] Trial 19 finished with value: 0.09900085066028647 and parameters: {'num_iterations': 322, 'learning_rate': 0.024143997100202565, 'num_leaves': 237, 'subsample': 0.5868312329670715, 'colsample_bytree': 0.5319852020720307, 'min_data_in_leaf': 50, 'max_bin': 484}. Best is trial 19 with value: 0.09900085066028647.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:19,898] Trial 20 finished with value: 0.09855008619784114 and parameters: {'num_iterations': 436, 'learning_rate': 0.024353277464488426, 'num_leaves': 257, 'subsample': 0.5027957381682637, 'colsample_bytree': 0.5322938114085973, 'min_data_in_leaf': 45, 'max_bin': 507}. Best is trial 20 with value: 0.09855008619784114.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:21,770] Trial 21 finished with value: 0.09826989026504272 and parameters: {'num_iterations': 449, 'learning_rate': 0.02444271981345191, 'num_leaves': 244, 'subsample': 0.508181841959746, 'colsample_bytree': 0.535474961759203, 'min_data_in_leaf': 45, 'max_bin': 511}. Best is trial 21 with value: 0.09826989026504272.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:23,501] Trial 22 finished with value: 0.09868811388506968 and parameters: {'num_iterations': 426, 'learning_rate': 0.024928064062044876, 'num_leaves': 227, 'subsample': 0.5108533178063512, 'colsample_bytree': 0.5521817474231544, 'min_data_in_leaf': 45, 'max_bin': 485}. Best is trial 21 with value: 0.09826989026504272.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:25,410] Trial 23 finished with value: 0.101186539598342 and parameters: {'num_iterations': 441, 'learning_rate': 0.011808615770855907, 'num_leaves': 243, 'subsample': 0.4964091686768481, 'colsample_bytree': 0.6006654701970364, 'min_data_in_leaf': 43, 'max_bin': 441}. Best is trial 21 with value: 0.09826989026504272.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:27,582] Trial 24 finished with value: 0.09837883166117221 and parameters: {'num_iterations': 416, 'learning_rate': 0.02688467615302018, 'num_leaves': 74, 'subsample': 0.49518404785461256, 'colsample_bytree': 0.7043607235937928, 'min_data_in_leaf': 26, 'max_bin': 488}. Best is trial 21 with value: 0.09826989026504272.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:30,349] Trial 25 finished with value: 0.09983456556622736 and parameters: {'num_iterations': 496, 'learning_rate': 0.01048992755728952, 'num_leaves': 89, 'subsample': 0.3495883211802232, 'colsample_bytree': 0.7044556511597244, 'min_data_in_leaf': 23, 'max_bin': 512}. Best is trial 21 with value: 0.09826989026504272.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:32,477] Trial 26 finished with value: 0.09724859505997677 and parameters: {'num_iterations': 405, 'learning_rate': 0.032255977179328606, 'num_leaves': 69, 'subsample': 0.4752654722814334, 'colsample_bytree': 0.6998982139362145, 'min_data_in_leaf': 18, 'max_bin': 483}. Best is trial 26 with value: 0.09724859505997677.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:34,966] Trial 27 finished with value: 0.0985017645007215 and parameters: {'num_iterations': 560, 'learning_rate': 0.034550753348930485, 'num_leaves': 66, 'subsample': 0.3840831947889063, 'colsample_bytree': 0.7119848064169212, 'min_data_in_leaf': 24, 'max_bin': 431}. Best is trial 26 with value: 0.09724859505997677.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:38,984] Trial 28 finished with value: 0.10594695777330274 and parameters: {'num_iterations': 402, 'learning_rate': 0.082824069774592, 'num_leaves': 167, 'subsample': 0.2777274394761205, 'colsample_bytree': 0.6875560392847851, 'min_data_in_leaf': 10, 'max_bin': 483}. Best is trial 26 with value: 0.09724859505997677.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:44,077] Trial 29 finished with value: 0.09771746533447226 and parameters: {'num_iterations': 490, 'learning_rate': 0.03593426683260922, 'num_leaves': 310, 'subsample': 0.4663520039199793, 'colsample_bytree': 0.7779564432167838, 'min_data_in_leaf': 17, 'max_bin': 412}. Best is trial 26 with value: 0.09724859505997677.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:45,561] Trial 30 finished with value: 0.10545587925252935 and parameters: {'num_iterations': 487, 'learning_rate': 0.038723177124478904, 'num_leaves': 314, 'subsample': 0.12022027433246463, 'colsample_bytree': 0.7503303120273165, 'min_data_in_leaf': 18, 'max_bin': 405}. Best is trial 26 with value: 0.09724859505997677.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:49,364] Trial 31 finished with value: 0.09617604651943676 and parameters: {'num_iterations': 403, 'learning_rate': 0.028789310129374017, 'num_leaves': 181, 'subsample': 0.4675357472144145, 'colsample_bytree': 0.6479654788396099, 'min_data_in_leaf': 18, 'max_bin': 467}. Best is trial 31 with value: 0.09617604651943676.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:53,984] Trial 32 finished with value: 0.09620942781317063 and parameters: {'num_iterations': 458, 'learning_rate': 0.03385513696274494, 'num_leaves': 451, 'subsample': 0.45289206324417286, 'colsample_bytree': 0.6254088112812645, 'min_data_in_leaf': 16, 'max_bin': 452}. Best is trial 31 with value: 0.09617604651943676.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:01:59,092] Trial 33 finished with value: 0.09926480372363591 and parameters: {'num_iterations': 537, 'learning_rate': 0.044729444108682535, 'num_leaves': 442, 'subsample': 0.4425634703395215, 'colsample_bytree': 0.6302150338937746, 'min_data_in_leaf': 17, 'max_bin': 447}. Best is trial 31 with value: 0.09617604651943676.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:02:04,067] Trial 34 finished with value: 0.10062032387239293 and parameters: {'num_iterations': 390, 'learning_rate': 0.08473918645128618, 'num_leaves': 450, 'subsample': 0.4641676447184908, 'colsample_bytree': 0.8271054632107655, 'min_data_in_leaf': 15, 'max_bin': 422}. Best is trial 31 with value: 0.09617604651943676.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:02:06,695] Trial 35 finished with value: 0.0980641060099865 and parameters: {'num_iterations': 472, 'learning_rate': 0.04008808799979274, 'num_leaves': 160, 'subsample': 0.4004816218923592, 'colsample_bytree': 0.7752853193758176, 'min_data_in_leaf': 29, 'max_bin': 385}. Best is trial 31 with value: 0.09617604651943676.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:02:08,755] Trial 36 finished with value: 0.10652484271239275 and parameters: {'num_iterations': 355, 'learning_rate': 0.09155890980623026, 'num_leaves': 319, 'subsample': 0.2844753080256315, 'colsample_bytree': 0.6439652339367616, 'min_data_in_leaf': 21, 'max_bin': 460}. Best is trial 31 with value: 0.09617604651943676.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:02:14,859] Trial 37 finished with value: 0.09870379148332452 and parameters: {'num_iterations': 525, 'learning_rate': 0.0615064344989979, 'num_leaves': 181, 'subsample': 0.4542378624785329, 'colsample_bytree': 0.8860735325944366, 'min_data_in_leaf': 12, 'max_bin': 387}. Best is trial 31 with value: 0.09617604651943676.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:02:17,055] Trial 38 finished with value: 0.09965588521425686 and parameters: {'num_iterations': 385, 'learning_rate': 0.01446211199479129, 'num_leaves': 487, 'subsample': 0.3619652606648704, 'colsample_bytree': 0.793945343320655, 'min_data_in_leaf': 28, 'max_bin': 466}. Best is trial 31 with value: 0.09617604651943676.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:02:21,669] Trial 39 finished with value: 0.09722897248788674 and parameters: {'num_iterations': 466, 'learning_rate': 0.008993729414590894, 'num_leaves': 610, 'subsample': 0.5526238372721108, 'colsample_bytree': 0.7392015386358575, 'min_data_in_leaf': 19, 'max_bin': 440}. Best is trial 31 with value: 0.09617604651943676.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:02:24,867] Trial 40 finished with value: 0.10495072813021611 and parameters: {'num_iterations': 407, 'learning_rate': 0.007411962029700292, 'num_leaves': 628, 'subsample': 0.5441400244791929, 'colsample_bytree': 0.5880298306635172, 'min_data_in_leaf': 21, 'max_bin': 439}. Best is trial 31 with value: 0.09617604651943676.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:02:29,548] Trial 41 finished with value: 0.14758186116791663 and parameters: {'num_iterations': 462, 'learning_rate': 0.00328964020219122, 'num_leaves': 327, 'subsample': 0.45958225129160546, 'colsample_bytree': 0.7615056287612867, 'min_data_in_leaf': 15, 'max_bin': 417}. Best is trial 31 with value: 0.09617604651943676.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:02:35,600] Trial 42 finished with value: 0.09529428683383619 and parameters: {'num_iterations': 491, 'learning_rate': 0.019289382249532416, 'num_leaves': 642, 'subsample': 0.6016582038490093, 'colsample_bytree': 0.665231685884678, 'min_data_in_leaf': 15, 'max_bin': 394}. Best is trial 42 with value: 0.09529428683383619.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:02:45,747] Trial 43 finished with value: 0.09517544770515986 and parameters: {'num_iterations': 554, 'learning_rate': 0.018395632612905947, 'num_leaves': 817, 'subsample': 0.5980770629194265, 'colsample_bytree': 0.6402035335390064, 'min_data_in_leaf': 10, 'max_bin': 395}. Best is trial 43 with value: 0.09517544770515986.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:02:55,660] Trial 44 finished with value: 0.0945953681426492 and parameters: {'num_iterations': 599, 'learning_rate': 0.017802288798267896, 'num_leaves': 822, 'subsample': 0.5951577739592602, 'colsample_bytree': 0.6654426746122315, 'min_data_in_leaf': 11, 'max_bin': 395}. Best is trial 44 with value: 0.0945953681426492.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:03:07,177] Trial 45 finished with value: 0.09497790425470963 and parameters: {'num_iterations': 597, 'learning_rate': 0.01937791824820128, 'num_leaves': 902, 'subsample': 0.6578544425101376, 'colsample_bytree': 0.581328015715865, 'min_data_in_leaf': 10, 'max_bin': 364}. Best is trial 44 with value: 0.0945953681426492.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:03:17,435] Trial 46 finished with value: 0.09438415606050603 and parameters: {'num_iterations': 586, 'learning_rate': 0.014981260301534944, 'num_leaves': 934, 'subsample': 0.6587413691527152, 'colsample_bytree': 0.6669712068439242, 'min_data_in_leaf': 11, 'max_bin': 368}. Best is trial 46 with value: 0.09438415606050603.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:03:29,721] Trial 47 finished with value: 0.09478043082169334 and parameters: {'num_iterations': 600, 'learning_rate': 0.017482879038704963, 'num_leaves': 940, 'subsample': 0.6714795770212095, 'colsample_bytree': 0.6715004658805579, 'min_data_in_leaf': 10, 'max_bin': 369}. Best is trial 46 with value: 0.09438415606050603.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:03:40,470] Trial 48 finished with value: 0.09501360592654842 and parameters: {'num_iterations': 599, 'learning_rate': 0.014207439968853564, 'num_leaves': 941, 'subsample': 0.653642826987169, 'colsample_bytree': 0.5775937734635671, 'min_data_in_leaf': 10, 'max_bin': 368}. Best is trial 46 with value: 0.09438415606050603.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:03:51,612] Trial 49 finished with value: 0.09417237678719997 and parameters: {'num_iterations': 597, 'learning_rate': 0.013889330816839742, 'num_leaves': 944, 'subsample': 0.6772172312480798, 'colsample_bytree': 0.5769483924570232, 'min_data_in_leaf': 10, 'max_bin': 368}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:03:59,536] Trial 50 finished with value: 0.10391481203776777 and parameters: {'num_iterations': 573, 'learning_rate': 0.0053313526163740734, 'num_leaves': 944, 'subsample': 0.7427927906262567, 'colsample_bytree': 0.48204027874572075, 'min_data_in_leaf': 13, 'max_bin': 370}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:04:09,429] Trial 51 finished with value: 0.09430179431965677 and parameters: {'num_iterations': 592, 'learning_rate': 0.013693010365189972, 'num_leaves': 951, 'subsample': 0.6672851199171708, 'colsample_bytree': 0.5808769463769987, 'min_data_in_leaf': 11, 'max_bin': 366}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:04:14,296] Trial 52 finished with value: 0.09546977045223079 and parameters: {'num_iterations': 600, 'learning_rate': 0.01205780146274467, 'num_leaves': 896, 'subsample': 0.6627736217999156, 'colsample_bytree': 0.5703176477930435, 'min_data_in_leaf': 23, 'max_bin': 352}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:04:22,573] Trial 53 finished with value: 0.09422968992501278 and parameters: {'num_iterations': 577, 'learning_rate': 0.01868978418454172, 'num_leaves': 984, 'subsample': 0.6972062260983334, 'colsample_bytree': 0.59331944602277, 'min_data_in_leaf': 13, 'max_bin': 337}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:04:30,320] Trial 54 finished with value: 0.09509479401706693 and parameters: {'num_iterations': 549, 'learning_rate': 0.009312543649299237, 'num_leaves': 1022, 'subsample': 0.6959346605946782, 'colsample_bytree': 0.6116154461652628, 'min_data_in_leaf': 13, 'max_bin': 328}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:04:33,933] Trial 55 finished with value: 0.09617601921910696 and parameters: {'num_iterations': 570, 'learning_rate': 0.013225401955938557, 'num_leaves': 963, 'subsample': 0.7325184580223274, 'colsample_bytree': 0.669642880647629, 'min_data_in_leaf': 35, 'max_bin': 315}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:04:35,876] Trial 56 finished with value: 0.09799953076577324 and parameters: {'num_iterations': 518, 'learning_rate': 0.017148212193362048, 'num_leaves': 757, 'subsample': 0.7717149423185603, 'colsample_bytree': 0.5053714244044223, 'min_data_in_leaf': 63, 'max_bin': 339}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:04:40,203] Trial 57 finished with value: 0.09525124203488078 and parameters: {'num_iterations': 580, 'learning_rate': 0.020118735738034677, 'num_leaves': 980, 'subsample': 0.6259492833230623, 'colsample_bytree': 0.557868820813514, 'min_data_in_leaf': 25, 'max_bin': 377}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:04:47,105] Trial 58 finished with value: 0.09509557691730781 and parameters: {'num_iterations': 549, 'learning_rate': 0.015100143046431503, 'num_leaves': 815, 'subsample': 0.6834902463206709, 'colsample_bytree': 0.461939550074183, 'min_data_in_leaf': 13, 'max_bin': 357}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:04:52,051] Trial 59 finished with value: 0.09714775661982221 and parameters: {'num_iterations': 582, 'learning_rate': 0.0077249610755667575, 'num_leaves': 870, 'subsample': 0.6316035643512824, 'colsample_bytree': 0.6056289242940616, 'min_data_in_leaf': 21, 'max_bin': 339}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:04:53,832] Trial 60 finished with value: 0.10064266730508366 and parameters: {'num_iterations': 536, 'learning_rate': 0.011608415683636995, 'num_leaves': 922, 'subsample': 0.7934217529750744, 'colsample_bytree': 0.7283922670614534, 'min_data_in_leaf': 87, 'max_bin': 276}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:05:05,080] Trial 61 finished with value: 0.09474299151123004 and parameters: {'num_iterations': 600, 'learning_rate': 0.02127043164510002, 'num_leaves': 910, 'subsample': 0.6714827610809078, 'colsample_bytree': 0.5870149150630724, 'min_data_in_leaf': 10, 'max_bin': 358}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:05:14,241] Trial 62 finished with value: 0.09427960833609958 and parameters: {'num_iterations': 570, 'learning_rate': 0.01989438598440212, 'num_leaves': 856, 'subsample': 0.6856650789111368, 'colsample_bytree': 0.673366096842071, 'min_data_in_leaf': 13, 'max_bin': 376}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:05:21,379] Trial 63 finished with value: 0.09503231997878592 and parameters: {'num_iterations': 564, 'learning_rate': 0.021489755900986174, 'num_leaves': 866, 'subsample': 0.7070251970686867, 'colsample_bytree': 0.5303355172317586, 'min_data_in_leaf': 15, 'max_bin': 379}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:05:28,712] Trial 64 finished with value: 0.09554379784869321 and parameters: {'num_iterations': 580, 'learning_rate': 0.025830349722948353, 'num_leaves': 772, 'subsample': 0.5816755764846128, 'colsample_bytree': 0.6056741890589286, 'min_data_in_leaf': 14, 'max_bin': 399}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:05:33,898] Trial 65 finished with value: 0.09680640234683993 and parameters: {'num_iterations': 509, 'learning_rate': 0.04908355939810602, 'num_leaves': 973, 'subsample': 0.6404713492181091, 'colsample_bytree': 0.682193157735394, 'min_data_in_leaf': 20, 'max_bin': 357}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:05:38,213] Trial 66 finished with value: 0.09629452642033276 and parameters: {'num_iterations': 542, 'learning_rate': 0.028085001017630732, 'num_leaves': 1003, 'subsample': 0.7103011344307231, 'colsample_bytree': 0.6380877011459217, 'min_data_in_leaf': 27, 'max_bin': 345}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:05:44,944] Trial 67 finished with value: 0.0949172573690739 and parameters: {'num_iterations': 557, 'learning_rate': 0.01509363620891256, 'num_leaves': 835, 'subsample': 0.6143935289852483, 'colsample_bytree': 0.5631409302329233, 'min_data_in_leaf': 13, 'max_bin': 317}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:05:48,639] Trial 68 finished with value: 0.09635893239637858 and parameters: {'num_iterations': 586, 'learning_rate': 0.01096168508319931, 'num_leaves': 792, 'subsample': 0.676041714343416, 'colsample_bytree': 0.7210089332346118, 'min_data_in_leaf': 32, 'max_bin': 291}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:05:50,210] Trial 69 finished with value: 0.09939463922505093 and parameters: {'num_iterations': 567, 'learning_rate': 0.02106829476597786, 'num_leaves': 886, 'subsample': 0.7229646865194982, 'colsample_bytree': 0.5113904380586738, 'min_data_in_leaf': 95, 'max_bin': 358}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:05:50,690] Trial 70 finished with value: 0.1109120336695587 and parameters: {'num_iterations': 100, 'learning_rate': 0.03089033484390466, 'num_leaves': 913, 'subsample': 0.7458057563984108, 'colsample_bytree': 0.5936434186804367, 'min_data_in_leaf': 80, 'max_bin': 378}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:06:03,732] Trial 71 finished with value: 0.0945813679228567 and parameters: {'num_iterations': 590, 'learning_rate': 0.01708532526381141, 'num_leaves': 930, 'subsample': 0.6583191654454934, 'colsample_bytree': 0.6713394876773203, 'min_data_in_leaf': 10, 'max_bin': 371}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:06:11,571] Trial 72 finished with value: 0.09419723047163728 and parameters: {'num_iterations': 585, 'learning_rate': 0.013526450965803086, 'num_leaves': 850, 'subsample': 0.6787701378061082, 'colsample_bytree': 0.6885612993619709, 'min_data_in_leaf': 17, 'max_bin': 391}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:06:18,647] Trial 73 finished with value: 0.0946511905488611 and parameters: {'num_iterations': 511, 'learning_rate': 0.012559841171535961, 'num_leaves': 701, 'subsample': 0.6930005236611024, 'colsample_bytree': 0.680152559077516, 'min_data_in_leaf': 16, 'max_bin': 389}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:06:24,763] Trial 74 finished with value: 0.09496669317303626 and parameters: {'num_iterations': 530, 'learning_rate': 0.0161460345485607, 'num_leaves': 859, 'subsample': 0.6298684465332756, 'colsample_bytree': 0.7036898793649751, 'min_data_in_leaf': 19, 'max_bin': 403}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:06:29,515] Trial 75 finished with value: 0.09639644372751446 and parameters: {'num_iterations': 587, 'learning_rate': 0.01020827041387805, 'num_leaves': 955, 'subsample': 0.5699288226605623, 'colsample_bytree': 0.6266205895833263, 'min_data_in_leaf': 23, 'max_bin': 373}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:06:39,269] Trial 76 finished with value: 0.09428932980140978 and parameters: {'num_iterations': 573, 'learning_rate': 0.013956243200979672, 'num_leaves': 996, 'subsample': 0.6467580010989981, 'colsample_bytree': 0.6562200829379546, 'min_data_in_leaf': 12, 'max_bin': 384}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:06:45,844] Trial 77 finished with value: 0.09630046200787247 and parameters: {'num_iterations': 564, 'learning_rate': 0.007896913723458038, 'num_leaves': 996, 'subsample': 0.6515479650745423, 'colsample_bytree': 0.7375554025985703, 'min_data_in_leaf': 18, 'max_bin': 332}. Best is trial 49 with value: 0.09417237678719997.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:06:56,107] Trial 78 finished with value: 0.09383876878890121 and parameters: {'num_iterations': 552, 'learning_rate': 0.013436493534440383, 'num_leaves': 985, 'subsample': 0.764884507170416, 'colsample_bytree': 0.6573794617181706, 'min_data_in_leaf': 13, 'max_bin': 384}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:06:58,981] Trial 79 finished with value: 0.0978017173707805 and parameters: {'num_iterations': 542, 'learning_rate': 0.013128735302397658, 'num_leaves': 1020, 'subsample': 0.7834525257369451, 'colsample_bytree': 0.6206573131994223, 'min_data_in_leaf': 54, 'max_bin': 384}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:07:04,910] Trial 80 finished with value: 0.0957677609614094 and parameters: {'num_iterations': 573, 'learning_rate': 0.009635865547789732, 'num_leaves': 979, 'subsample': 0.7587076327847998, 'colsample_bytree': 0.5476107950514282, 'min_data_in_leaf': 21, 'max_bin': 364}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:07:14,771] Trial 81 finished with value: 0.09459885054272153 and parameters: {'num_iterations': 586, 'learning_rate': 0.024866760435161707, 'num_leaves': 938, 'subsample': 0.7191993464103332, 'colsample_bytree': 0.6482839778940601, 'min_data_in_leaf': 13, 'max_bin': 351}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:07:22,711] Trial 82 finished with value: 0.09417744096793124 and parameters: {'num_iterations': 555, 'learning_rate': 0.015004497399503441, 'num_leaves': 994, 'subsample': 0.6961846166810569, 'colsample_bytree': 0.6953406568254931, 'min_data_in_leaf': 16, 'max_bin': 376}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:07:30,734] Trial 83 finished with value: 0.09453349261146564 and parameters: {'num_iterations': 559, 'learning_rate': 0.013536054396688871, 'num_leaves': 1002, 'subsample': 0.6922063132219414, 'colsample_bytree': 0.696158688512755, 'min_data_in_leaf': 16, 'max_bin': 390}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:07:38,117] Trial 84 finished with value: 0.09462091676747042 and parameters: {'num_iterations': 524, 'learning_rate': 0.011369720498638266, 'num_leaves': 973, 'subsample': 0.7186606375873353, 'colsample_bytree': 0.7271263982471218, 'min_data_in_leaf': 17, 'max_bin': 379}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:07:43,007] Trial 85 finished with value: 0.09405009241762947 and parameters: {'num_iterations': 229, 'learning_rate': 0.02206322532578161, 'num_leaves': 884, 'subsample': 0.8158332760264361, 'colsample_bytree': 0.6550971707967728, 'min_data_in_leaf': 12, 'max_bin': 418}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:07:45,363] Trial 86 finished with value: 0.09622784352030396 and parameters: {'num_iterations': 245, 'learning_rate': 0.029488719864478527, 'num_leaves': 890, 'subsample': 0.8167282309167053, 'colsample_bytree': 0.6491851956781841, 'min_data_in_leaf': 30, 'max_bin': 421}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:07:48,135] Trial 87 finished with value: 0.09852431837261492 and parameters: {'num_iterations': 155, 'learning_rate': 0.023002121847972103, 'num_leaves': 847, 'subsample': 0.7580574015590201, 'colsample_bytree': 0.6233645422547278, 'min_data_in_leaf': 14, 'max_bin': 413}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:07:52,761] Trial 88 finished with value: 0.09514598940492469 and parameters: {'num_iterations': 327, 'learning_rate': 0.0377530961921753, 'num_leaves': 1023, 'subsample': 0.8619444943860897, 'colsample_bytree': 0.7517257933286223, 'min_data_in_leaf': 23, 'max_bin': 426}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:07:54,120] Trial 89 finished with value: 0.09902735015056592 and parameters: {'num_iterations': 192, 'learning_rate': 0.023992531971537875, 'num_leaves': 957, 'subsample': 0.7304750585276065, 'colsample_bytree': 0.6959983573762247, 'min_data_in_leaf': 40, 'max_bin': 409}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:07:56,783] Trial 90 finished with value: 0.14773145686694172 and parameters: {'num_iterations': 243, 'learning_rate': 0.006326044641643268, 'num_leaves': 879, 'subsample': 0.6829993302514128, 'colsample_bytree': 0.6060488286587078, 'min_data_in_leaf': 19, 'max_bin': 401}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:08:05,942] Trial 91 finished with value: 0.09440219904014263 and parameters: {'num_iterations': 575, 'learning_rate': 0.01500639272606389, 'num_leaves': 994, 'subsample': 0.6097489630651677, 'colsample_bytree': 0.6523034211807773, 'min_data_in_leaf': 12, 'max_bin': 384}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:08:14,379] Trial 92 finished with value: 0.09426950127061176 and parameters: {'num_iterations': 550, 'learning_rate': 0.018939116855203126, 'num_leaves': 921, 'subsample': 0.7031707070762325, 'colsample_bytree': 0.7155527727436956, 'min_data_in_leaf': 15, 'max_bin': 363}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:08:22,314] Trial 93 finished with value: 0.09415805163079671 and parameters: {'num_iterations': 549, 'learning_rate': 0.01881005062562729, 'num_leaves': 905, 'subsample': 0.7055197155971543, 'colsample_bytree': 0.7176445316107809, 'min_data_in_leaf': 16, 'max_bin': 362}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:08:29,812] Trial 94 finished with value: 0.09487979153099182 and parameters: {'num_iterations': 503, 'learning_rate': 0.018634618759364865, 'num_leaves': 919, 'subsample': 0.744500652466916, 'colsample_bytree': 0.7141245790010106, 'min_data_in_leaf': 17, 'max_bin': 393}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:08:38,660] Trial 95 finished with value: 0.09535519621055269 and parameters: {'num_iterations': 538, 'learning_rate': 0.03314292141857536, 'num_leaves': 903, 'subsample': 0.7039533405872194, 'colsample_bytree': 0.7743122006670745, 'min_data_in_leaf': 15, 'max_bin': 362}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:08:40,802] Trial 96 finished with value: 0.09727501828292842 and parameters: {'num_iterations': 479, 'learning_rate': 0.02241373688772677, 'num_leaves': 847, 'subsample': 0.7758196719359597, 'colsample_bytree': 0.6886086769260448, 'min_data_in_leaf': 70, 'max_bin': 376}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:08:47,107] Trial 97 finished with value: 0.09467396691287402 and parameters: {'num_iterations': 546, 'learning_rate': 0.01701822391515577, 'num_leaves': 794, 'subsample': 0.7007443032708075, 'colsample_bytree': 0.7512641458539212, 'min_data_in_leaf': 20, 'max_bin': 349}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:08:52,410] Trial 98 finished with value: 0.09665694112795198 and parameters: {'num_iterations': 559, 'learning_rate': 0.0270776256590368, 'num_leaves': 980, 'subsample': 0.6422738015156731, 'colsample_bytree': 0.8013972377994859, 'min_data_in_leaf': 25, 'max_bin': 341}. Best is trial 78 with value: 0.09383876878890121.
# /Users/kogby/miniconda3/envs/Jupyter/lib/python3.9/site-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2023-11-11 17:09:03,270] Trial 99 finished with value: 0.09404254190037788 and parameters: {'num_iterations': 531, 'learning_rate': 0.019421407468210857, 'num_leaves': 740, 'subsample': 0.8005970927953098, 'colsample_bytree': 0.7328457016663164, 'min_data_in_leaf': 12, 'max_bin': 334}. Best is trial 78 with value: 0.09383876878890121.

# %%
print('Best hyperparameters:', study.best_params)
print('Best MAPE:', study.best_value)
# Out:
# Best hyperparameters: {'num_iterations': 552, 'learning_rate': 0.013436493534440383, 'num_leaves': 985, 'subsample': 0.764884507170416, 'colsample_bytree': 0.6573794617181706, 'min_data_in_leaf': 13, 'max_bin': 384}
# Best MAPE: 0.09383876878890121

# %%
pred.to_csv('data/pred.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pred.to_csv('data/pred.csv', index=False)
#
# NameError: name 'pred' is not defined
